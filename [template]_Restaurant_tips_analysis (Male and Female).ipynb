# %% [markdown]
# # **🍽️ Restaurant Tips Analysis**

# %% [markdown]
# ![restaurant.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# This project aims to use the restaurant tips dataset to practice creating composition plots and visualizations. We will examine the relationship between different variables and the tips given.

# %% [markdown]
# The dataset consists of information from 244 restaurant bills, collected in the US in 1987.

# %% [markdown]
# It includes details about the tips given to restaurant staff, such as the total bill, tip amount, gender of the person paying, smoking status, day of the week, time of day, and party size.

# %% [markdown]
# ## **👣 The First Steps**

# %% [markdown]
# ### **📥 Data import**

# %% [markdown]
# First, let's import the needed libraries: Pandas & Matplotlib.

# %%
# PUT YOUR CODE HERE
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Then load data from the following link: https://raw.githubusercontent.com/RusAbk/sca_datasets/main/tips.csv

# %%
# PUT YOUR CODE HERE
df = pd.read_csv('https://raw.githubusercontent.com/RusAbk/sca_datasets/main/tips.csv')

# %% [markdown]
# ### **🔍 Data exploration**

# %% [markdown]
# #### **Test sample**

# %% [markdown]
# Let's take a look at the first 5 rows to be sure, that data is loaded properly:

# %%
# PUT YOUR CODE HERE
df.head()
# Out:
#    id  total_bill   tip     sex smoker  day    time  size
# 0   0       16.99  1.01  Female     No  Sun  Dinner     2
# 1   1       10.34  1.66    Male     No  Sun  Dinner     3
# 2   2       21.01  3.50    Male     No  Sun  Dinner     3
# 3   3       23.68  3.31    Male     No  Sun  Dinner     2
# 4   4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# > 🎉 Great! It seems to be okay.
#
# As you can see each observation represents a customer who left a tip at a restaurant.
#
# We can see information about:
# * the day it occurred
# * if it was at lunch or dinner
# * the total bill
# * the sex of the person
# * if they were a smoker or not
# * the size of the party
#
# Before continuing take a look at a few rows of the data and use `info` and `describe` to analyze dataset column types and values.

# %% [markdown]
# #### **Column types checking**

# %% [markdown]
# Show the columns of the dataframe and their types:

# %%
# PUT YOUR CODE HERE
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          244 non-null    int64
#  1   total_bill  244 non-null    float64
#  2   tip         244 non-null    float64
#  3   sex         244 non-null    object
#  4   smoker      244 non-null    object
#  5   day         244 non-null    object
#  6   time        244 non-null    object
#  7   size        244 non-null    int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 15.4+ KB

# %% [markdown]
# > **Ooops... 🤔**
# >
# > We have string columns considered as objects.
#
# ![image.png](data:image/png;base64,...)
#
# Let's fix their types and make them string:

# %%
# PUT YOUR CODE HERE
df1 = df.convert_dtypes()

# %% [markdown]
# Check again (output columns and their types):

# %%
# PUT YOUR CODE HERE
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          244 non-null    Int64
#  1   total_bill  244 non-null    Float64
#  2   tip         244 non-null    Float64
#  3   sex         244 non-null    string
#  4   smoker      244 non-null    string
#  5   day         244 non-null    string
#  6   time        244 non-null    string
#  7   size        244 non-null    Int64
# dtypes: Float64(2), Int64(2), string(4)
# memory usage: 16.3 KB

# %% [markdown]
# Nice! We finished this. Look like we are ready to explore some statistics on the given data.

# %% [markdown]
# #### **Basic descriptive statistics**

# %% [markdown]
# Show a descriptive statistics of the numeric columns:

# %%
# PUT YOUR CODE HERE
df1.describe()
# Out:
#               id  total_bill       tip      size
# count      244.0       244.0     244.0     244.0
# mean       121.5   19.785943  2.998279  2.569672
# std    70.580923    8.902412  1.383638    0.9511
# min          0.0        3.07       1.0       1.0
# 25%        60.75     13.3475       2.0       2.0
# 50%        121.5      17.795       2.9       2.0
# 75%       182.25     24.1275    3.5625       3.0
# max        243.0       50.81      10.0       6.0

# %% [markdown]
# Great! Now we know a little more about our data.
#
# ➡️ Let's move forward!

# %% [markdown]
# ## **💸 Tip value influencers**

# %% [markdown]
# ### **🚬Do males give more tips?
#
#
# > Thêm khối trích dẫn
#
# > Thêm khối trích dẫn

# %% [markdown]
# Let's figure out the difference between male and female in terms of their behavior and purchasing habits in public catering establishments.

# %% [markdown]
# #### **Separate Male and Female

# %% [markdown]
# Create a new dataframe `male_df` containing only info about male.

# %%
# PUT YOUR CODE HERE
male_df  = df1.query('sex == "Male"')

# %% [markdown]
# Check whether everything is okay. Output a test sample (5 random rows):

# %%
# PUT YOUR CODE HERE
male_df.sample(5)
# Out:
#       id  total_bill   tip   sex smoker  day    time  size
# 167  167       31.71   4.5  Male     No  Sun  Dinner     4
# 5      5       25.29  4.71  Male     No  Sun  Dinner     4
# 55    55       19.49  3.51  Male     No  Sun  Dinner     2
# 69    69       15.01  2.09  Male    Yes  Sat  Dinner     2
# 220  220       12.16   2.2  Male    Yes  Fri   Lunch     2

# %% [markdown]
# Also create another one dataframe `Female_df` containing only Female.

# %%
# PUT YOUR CODE HERE
female_df  = df1.query('sex == "Female"')

# %% [markdown]
# Check whether everything is okay. Output a test sample (5 random rows):

# %%
# PUT YOUR CODE HERE
female_df .sample(5)
# Out:
#       id  total_bill   tip     sex smoker   day    time  size
# 37    37       16.93  3.07  Female     No   Sat  Dinner     3
# 57    57       26.41   1.5  Female     No   Sat  Dinner     2
# 66    66       16.45  2.47  Female     No   Sat  Dinner     2
# 22    22       15.77  2.23  Female     No   Sat  Dinner     2
# 131  131       20.27  2.83  Female     No  Thur   Lunch     2

# %% [markdown]
# #### **Compare their measures of central tendency**

# %% [markdown]
# As we know, measures of central tendency is one of the basic tools, that allow us to compare different datasets as it shows the most typical values.

# %% [markdown]
# ##### **🌏 Whole dataset**

# %% [markdown]
# Let's try to calculate measures of central tendency for the whole dataset first.
#
# Calculate them for the **'tip'** column through the whole dataset and save them into the following variables:
#
# * min => `common_tip_min`
# * max => `common_tip_max`
# * mean => `common_tip_mean`
# * median => `common_tip_median`

# %%
# YOUR CODE
common_tip_min = df1['tip'].min()
common_tip_max = df1['tip'].max()
common_tip_mean = df1['tip'].mean()
common_tip_median = df1['tip'].median()

# %% [markdown]
# Let's show the resulting values for whole dataset (we already have the code written for you 😉)

# %%
# Make a list of values
common_values = [common_tip_min, common_tip_max, common_tip_mean, common_tip_median]
# Round all the values to 4 decimal places
common_values = map(lambda x: round(x, 4), common_values)

# Make a dataframe from the list
common_mct = pd.DataFrame(common_values, index=['min', 'max', 'mean', 'median'])
# Output the dataframe
common_mct
# Out:
#               0
# min      1.0000
# max     10.0000
# mean     2.9983
# median   2.9000

# %% [markdown]
# ##### **🚬 Male**

# %% [markdown]
# Do the same taking into account only male. Use the following variables:
#
# * min => `Male_tip_min`
# * max => `Male_tip_max`
# * mean => `Male_tip_mean`
# * median => `Male_tip_median`

# %%
# YOUR CODE

male_tip_min = male_df['tip'].min()
male_tip_max = male_df['tip'].max()
male_tip_mean = male_df['tip'].mean()
male_tip_median = male_df['tip'].median()

# %% [markdown]
# Let's output the results in the same format.
#
# Make the same dataframe containing the measures of central tendency for smokers as we did for whole dataset. Then output it.

# %%
# YOUR CODE
# Make a list of values
common_values = [male_tip_min, male_tip_max, male_tip_mean, male_tip_median]
# Round all the values to 4 decimal places
common_values = map(lambda x: round(x, 4), common_values)

# Make a dataframe from the list
common_mct = pd.DataFrame(common_values, index=['min', 'max', 'mean', 'median'])
# Output the dataframe
common_mct
# Out:
#               0
# min      1.0000
# max     10.0000
# mean     3.0896
# median   3.0000

# %% [markdown]
# ##### **🚭 Non-smokers**

# %% [markdown]
# Now repeat it for Female. Use the following variables:
#
# * min => `female_tip_min`
# * max => `female_tip_max`
# * mean => `female_tip_mean`
# * median => `female_tip_median`

# %%
# YOUR CODE
female_tip_min = female_df['tip'].min()
female_tip_max = female_df['tip'].max()
female_tip_mean = female_df['tip'].mean()
female_tip_median = female_df['tip'].median()

# %% [markdown]
# Make the same dataframe containing the measures of central tendency for non-smokers as we did for whole dataset. Then output it.

# %%
# YOUR CODE
# Make a list of values
common_values = [female_tip_min, female_tip_max, female_tip_mean, female_tip_median]
# Round all the values to 4 decimal places
common_values = map(lambda x: round(x, 4), common_values)

# Make a dataframe from the list
common_mct = pd.DataFrame(common_values, index=['min', 'max', 'mean', 'median'])
# Output the dataframe
common_mct
# Out:
#              0
# min     1.0000
# max     6.5000
# mean    2.8334
# median  2.7500

# %% [markdown]
# ##### **📝 Conclusion**

# %% [markdown]
# Let's show the retrieved results together (we already have the code written for you 😉):

# %%
all_vals_dict = {
    'Common': {'min': common_tip_min, 'max': common_tip_max, 'mean': common_tip_mean, 'median': common_tip_median},
    'Male': {'min': male_tip_min, 'max': male_tip_max, 'mean': male_tip_mean, 'median': male_tip_median},
    'Female': {'min': female_tip_min, 'max': female_tip_max, 'mean': female_tip_mean, 'median': female_tip_median}
}

# Make a dataframe
all_mct = pd.DataFrame(all_vals_dict)
# Output the dataframe
all_mct
# Out:
#            Common       Male    Female
# min      1.000000   1.000000  1.000000
# max     10.000000  10.000000  6.500000
# mean     2.998279   3.089618  2.833448
# median   2.900000   3.000000  2.750000

# %% [markdown]
# **Insights based on measures of central tendency comparison:**

# %% [markdown]
# ---

# %% [markdown]
# 1. Insight 1: Nam có xu hướng bo tip cao hơn nữ
# - Mean (trung bình): Nam ≈ 3.09 > Nữ ≈ 2.83
#
# - Median (trung vị): Nam = 3.0 > Nữ = 2.75
#
#  &#8658; Điều này cho thấy nam giới thường bo tip nhiều hơn nữ cả về giá trị trung bình lẫn trung vị.
#
# 2. Insight 2:  Nữ có phân phối tip thấp hơn và ổn định hơn
# Median của nữ (2.75) thấp hơn so với median của nam (3.0), và cũng thấp hơn median chung (2.9).
#
#  &#8658;Điều này gợi ý rằng nữ thường bo các giá trị tip thấp hơn và ít dao động hơn, trong khi nam có thể có vài giá trị tip cao kéo mean lên.
#
# **General conclusion:**
# - Nam giới thường có xu hướng bo tip cao hơn nữ giới.
#
# - Nữ giới có xu hướng bo ở mức thấp hơn và đồng đều hơn, tức ít có sự chênh lệch lớn giữa các giá trị tip.
#
#  &#8658; Điều này có thể phản ánh sự khác biệt hành vi chi tiêu hoặc hoàn cảnh chi trả giữa hai giới.

# %% [markdown]
# #### **Look at histograms**

# %% [markdown]
# As we already discussed on the last lecture, there are a lot of cases, when comparing the measures of central tendency is not enough.
#
# This is because they only show the most typical values. However, the way data is distributed is equally important. There are situations where measures of central tendency are exactly the same, but due to different distributions, it is incorrect to say that the datasets are similar.

# %% [markdown]
# ##### **🌏 Whole dataset tips histogram**

# %% [markdown]
# Plot the histogram for the whole dataset tips distribution.
#
# <u>Use the following settings:</u>
# * Size: `15 x 5`
# * Color: `#74b9ff`
# * X-axis label: `Tip value`
# * Y-axis label: `Frequency`
# * Chart title: `Whole dataset tip values`
# * Gridlines: `show`

# %%
# YOUR CODE
plt.figure(figsize=(15, 5))
plt.hist(df1['tip'], bins=5, color='#74b9ff', edgecolor='black')
plt.xlabel('Tip value', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Whole dataset tip values', fontsize=16)
plt.grid(True)
plt.show()

# %% [markdown]
# ##### **🚬 Male tips histogram**

# %% [markdown]
# Plot the histogram for smokers tips distribution.
#
# <u>Use the following settings:</u>
# * Size: `15 x 5`
# * Color: `#ff7675`
# * X-axis label: `Tip value`
# * Y-axis label: `Frequency`
# * Chart title: `Male tip values`
# * Gridlines: `show`

# %%
# YOUR CODE

plt.figure(figsize=(15, 5))
plt.hist(male_df['tip'], bins=5, color='#ff7675', edgecolor='black')


plt.xlabel('Tip value', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Male tip values', fontsize=16)


plt.grid(True)


plt.show()

# %% [markdown]
# ##### **🚭 Female tips histogram**

# %% [markdown]
# Plot the histogram for non-smokers tips distribution.
#
# <u>Use the following settings:</u>
# * Size: `15 x 5`
# * Color: `#55efc4`
# * X-axis label: `Tip value`
# * Y-axis label: `Frequency`
# * Chart title: `Female tip values`
# * Gridlines: `show`

# %%
# YOUR CODE


plt.figure(figsize=(15, 5))
plt.hist(female_df['tip'], bins=5, color='#55efc4', edgecolor='black')
plt.xlabel('Tip value', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Female tip values', fontsize=16)
plt.grid(True)
plt.show()

# %% [markdown]
# ##### **⭐ Extra-task with a higher difficulty**

# %% [markdown]
# Plot all 3 charts in a row in the same cell:

# %%
# YOUR CODE

fig, axs = plt.subplots(1, 3, figsize=(18, 5))

# Whole dataset
axs[0].hist(df1['tip'], bins=5, color='#74b9ff', edgecolor='black')
axs[0].axvline(df1['tip'].median(), color='black', linestyle='--', label='Median')
axs[0].set_title('Whole dataset tip values')
axs[0].set_xlabel('Tip value')
axs[0].set_ylabel('Frequency')
axs[0].grid(True)
axs[0].legend()

# Smokers
axs[1].hist(male_df['tip'], bins=5, color='#ff7675', edgecolor='black')
axs[1].axvline(male_df['tip'].median(), color='black', linestyle='--', label='Median')
axs[1].set_title('Male tip values')
axs[1].set_xlabel('Tip value')
axs[1].grid(True)
axs[1].legend()

# Non-smokers
axs[2].hist(female_df['tip'], bins=5, color='#55efc4', edgecolor='black')
axs[2].axvline(female_df['tip'].median(), color='black', linestyle='--', label='Median')
axs[2].set_title('Non-smokers tip values')
axs[2].set_xlabel('Tip value')
axs[2].grid(True)
axs[2].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### **📝 Conclusion**

# %% [markdown]
# **Insights based on distribution comparison:**
#
# ---

# %% [markdown]
# 1. Insight 1
# - Male customers show a more right-skewed tip distribution, with several high-value tips pushing the average up.
#
# **General conclusion:**
# - Male customers tend to give higher tips than female customers, both in terms of average (mean) and typical (median) tip amounts.

# %% [markdown]
# ### **👨👩 Do males give more tips?**

# %% [markdown]
# Perform the same steps based on the column **sex**.

# %% [markdown]
# ### **📆 Do weekends bring more tips?**

# %% [markdown]
# Perform the same steps based on the column **day**.

# %% [markdown]
# ### **🕑 Do dinners bring more tips?**

# %% [markdown]
# Perform the same steps based on the column **time**.
